# %%
import pandas as pd

# %% [markdown]
# # Rain data

# %%
rain = pd.read_csv('data/rain_data_aus.csv',sep = ',')
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         sunshine  humidity9am  humidity3pm  pressure9am  ...  temp9am  \
# ...

# %% [markdown]
# # Removing NA

# %%
rain.isna().sum()
# Out:
# date                0
# location            0
# mintemp             0
# maxtemp             0
# rainfall            0
# humidity9am         0
# humidity3pm         0
# pressure9am         0
# pressure3pm         0
# temp9am             0
# temp3pm             0
# raintoday           0
# amountOfRain        0
# raintomorrow        0
# temp                0
# humidity            0
# precipitation3pm    0
# precipitation9am    0
# modelo_vigente      0
# dtype: int64

# %%
rain = rain[['date', 'location', 'mintemp', 'maxtemp', 'rainfall','humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm','temp9am', 'temp3pm', 'raintoday','amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm','precipitation9am', 'modelo_vigente']]
rain.dropna(inplace=True)

# %% [markdown]
# # Mudar para bolleano

# %%
rain
# Out:
#               date location  mintemp  maxtemp  rainfall  humidity9am  \
# 0       2008-12-01   Albury     13.4     22.9       0.6         71.0
# 1       2008-12-02   Albury      7.4     25.1       0.0         44.0
# 2       2008-12-03   Albury     12.9     25.7       0.0         38.0
# 3       2008-12-04   Albury      9.2     28.0       0.0         45.0
# 4       2008-12-05   Albury     17.5     32.3       1.0         82.0
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0         59.0
# 142189  2017-06-21    Uluru      2.8     23.4       0.0         51.0
# 142190  2017-06-22    Uluru      3.6     25.3       0.0         56.0
# 142191  2017-06-23    Uluru      5.4     26.9       0.0         53.0
# 142192  2017-06-24    Uluru      7.8     27.0       0.0         51.0
#
#         humidity3pm  pressure9am  pressure3pm  temp9am  temp3pm raintoday  \
# ...
